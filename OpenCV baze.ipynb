# %%
# !pip install opencv-contrib-python

# %%
# !pip install caer
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.5/809.5 kB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 74.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Чтение фото и видео**

# %%
import cv2 as cv

img_path = "/content/drive/MyDrive/open cv course/Чтение изображений и видео/cat1.jpg"
img = cv.imread(img_path) #принимает путь, возвращает в виде матрицы пикселей
cv.imshow('Cat', img) #отобразить изображение в новом окне (Имя окна, объект)
cv.waitKey(0) #функция привязка к клавиатуре

# %%
import cv2 as cv

#создание переменной для захвата видео (целое число для захвата с определённой камеры. 0-вебкмера, 1-камера usb)
capture = cv.VideoCapture("path")
#через цикл считываем видео кадр за кадром
while True:
  isTrue, frame  = capture.read()
  cv.imshow('Video', frame)
  #проигрываем 20 секунд
  if cv.waitKey(20) & 0xFF==ord('d'):
    break
capture.release() #зачищаем
cv.destroyAllWindows() #закрываем все окна

# %% [markdown]
# **Масштаб и размер**

# %%
import cv2 as cv

#
#...
#

def rescaleFrame(frame, scale):
  width = int(frame.shape[1] * 0.75)
  height = int(frame.shape[1] * 0.75)

  dimensions = (width,height)
  return cv.resize(frame, dimensions, interpolation=cv.INTER_AREA)

frame_res = rescaleFrame(frame, 0.5) #как к видео, так и к изображениям

#для видеотрансляции через свойства класса
def changeRes(width, height):
  capture.set(3, width)
  capture.set(4, )

# %% [markdown]
# **Как рисовать поверх изображения и видео?**

# %%
import cv2 as cv
import numpy as np

#1)рисовать на отдельных изображениях

#2)cоздать пустое изображение для работы
blank = np.zeros((500, 500), dtype='uint8') #пустое изображение
cv.imshow('Blank', blank)

#закрасить ищображение определённым цветом (через срез)
blank[:] = 0,255,0 #присвоить всем пиксеям
blank[200:300, 200:300] = 0,0,255 #закраска определённых пкселей
cv.imshow('Green',blank)

#нарисовать прямоугольник
cv.rectangle(blank, (0,0), (250, 250), (0,255,0), thickness=2)
cv.imshow('Rect', blank)
#thickness=cv.FILLED
cv.waitKey(0)

#нарисовать круг
сv.circle(...)
cv.imshow('Circle', blank)

#нарисоыать линию
cv.line(...)

#написать текст
cv.putText(blank,'Hello',

# %% [markdown]
# **Основные функции opencv**

# %%
gray = cv.cvtColor(img, ev.COLOR_BGR2) #перевод в ЧБ

#размытие по гауссу
blur = cv.cv.GaussianBlur(img, (3,3), cv.cv.BORDER_DEFAULT)

#создание каскада для поиска
canny = cv.Canny(img, 125, 175)

#расширение изображения (тонкие рёбра)
dilated = cv.dilate(canny, (3,3), iterations=1)

#размытие
eroded = cv.erode(dilated, (3,3), iterations=1)

#изменение размера
resized = cv.resize(img, (500,500), interpolation=cv.INTER  CUB)

#копировани
cropped = (img=200, 200:400)

#разворот
flip = cv.flip(img, int)
cv.cv.imshow('Flip', flip)

#обрезка
cropped = img[200:400, 300:400]

# %% [markdown]
# **Определение контуров (границ оъектов)**
# Математически контур и края не одно и то же

# %%
import cv2 as cv

img = cv.imread('cat2.jpg')
cv.imshow('Cat', img)

gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
cv.imshow('Gray', gray)

canny = cv.Canny(img, 125, 175)
cv.imshow('Canny', canny)

contours, hierarchies = cv.findContours(canny, cv.RETR_LIST, cv.CHAIN_APPROX_NONE)
cv.waitKey(0)

# %% [markdown]
# **Работа с цветом**

# %%
#bgr -> gray (распределение интенсивности)
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

#hsv (интенсивность и насыенность)
hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)

#lab
lab = cv.cvtColor(img, cv.COLOR_BGR2LAB)

#bgr to rgb
rgb = cv.cvtColo

# %% [markdown]
# **Цветовык каналы**

# %%
import cv2 as cv

img = cv.imread('cat2.jpg')
cv.imshow('Cat', img)

b,g,r = cv.split(img) #выделить rgb слои

cv.imshow('Blue', img)
cv.imshow('Green', img)
cv.imshow('Red', img)

blank = np.zeros(img.shape[:2], dtype='uint8')
#объединение слоёв
new = сv.merge([blank,g,blank])
cv.waitKey(0)

# %% [markdown]
# **Сглаживание и размытие**
# Сглаживаем из-за наличия шума

# %%
#используется сетка (ядро)

#метод среднего
average = cv.blur(img, (3,3))

#размытие по гауссу (через весы, более естесвенно)
gauss = cv.GaussianBlur(img, (7,7), 0)

#медианное
median = cv.medianBlur(img,3)

#двусторонее (сохраняет края изображения)
bilateral = cv.bilateralFilter(img, 5, 15, 15)

# %% [markdown]
# Побитовые операторы

# %%
import cv2 as cv
import numpy as np

blank = np.zeros((400,400), dtype='uint8')

rectangle = cv.rectangle(blank.copy(), (30,30), (370,370), 255, -1)
circle = cv.circle(blank.copy(), (200,200), 200, 255, -1)

cv.imshow("Rectangle", rectangle)
cv.imshow("Circle", circle)

#битовый AND
bitwise_and = cv.bitwise_and(rectangle, circle)

#битовый OR
bitwise_or = cv.bitwise_or(rectangle, circle)

#битовый XOR
bitwise_xor = cv.bitwise_xor(rectangle, circle)

#битовый NOT
bitwise_not = cv.bitwise_not(rectangle, circle)

cv.waitKey(0)

# %% [markdown]
# **Маскирование**. Помогает для фокусировки

# %%
import cv2 as cv
import numpy as np

img = cv.imread('cats.jpg')
cv.imshow('Cats', img)

blank = np.zeros(img.shape[:2], device='uint8') #пустая чёрная картинка
#маска должна иметь тот же размер

cv.imshow('Blank Image', blank)

mask = cv.circle(blank, (img.shape[1]//2, img.shape[0]//2), 100, 255, -1)
cv.imshow('Mask', mask)

masked = cv.bitwise_and(img, mask, mask=mask)

cv.waitKey(0)

# %% [markdown]
# **Гистограммы**
# Позволяют визуализировать распределение интенсивности пикселей в изображении

# %%
import cv2 as cv
import matplotlib.pyplot as plt

img = cv.imread('cats.jpg')
cv.imshow('Cats', img)

gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
cv.imshow('Gray', gray)

gray_hist = cv.calcHist([gray], [0], None, [256], [0,256])

plt.figure()
plt.title('Histogram')
plt.xlabel('Bins')
plt.ylabel('# of pixels')
plt.plot(gray_hist)
plt.xlim([0,256])
plt.show()

#можно создать маску и вычислить отдельно для неё гистограмму
cv.waitKey(0)

# %% [markdown]
# **Пороговые значения. Бинаризация изображения (0, 1 / 0, 255)**

# %%
import cv2 as cv
import matplotlib.pyplot as plt

img = cv.imread('cats.jpg')
cv.imshow('Cats', img)

gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
cv.imshow('Gray', gray)

#простая пороговая обработка
thereshold, thresh = cv.threshold(gray, 150, 255, cv.THRESH_BINARY)
cv.imshow("Tresh", thresh)

thereshold, thresh_inv = cv.threshold(gray, 150, 255, cv.THRESH_BINARY_INV)
cv.imshow("Tresh INV", thresh_inv)

#адаптивный порог (мы не устанавливаем сами порогове значение)
adaptive_thresh = cv.adaptiveThreshold(gray, 255, cv.ADAPTIVE_THRESH_MEAN_C, cv.THRESH_BINARY, 11, 3)
cv.imshow("Adaptive Thereshold", adaptive_thresh)


cv.waitKey(0)

# %% [markdown]
# **Градиенты. Обнаружение границ**

# %%
import cv2 as cv
import numpy as np

# Загрузка изображения
img = cv.imread('cats.jpg')
if img is None:
    print("Ошибка: Не удалось загрузить изображение.")
    exit()

# Показ исходного изображения
cv.imshow('Cats', img)

# Преобразование в grayscale (исправлено: COLOR_BGR2GRAY вместо COLOR_BAYER_BG2GRAY)
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
cv.imshow('Gray', gray)

# 1) Метод Лапласа
# Применение оператора Лапласа
lap = cv.Laplacian(gray, cv.CV_64F)  # CV_64F для сохранения отрицательных значений
lap = np.uint8(np.absolute(lap))  # Преобразование в абсолютные значения и uint8
cv.imshow('Laplacian', lap)

# 2) Метод Собеля
# Применение оператора Собеля по оси X и Y
sobelx = cv.Sobel(gray, cv.CV_64F, 1, 0)  # Градиент по X
sobely = cv.Sobel(gray, cv.CV_64F, 0, 1)  # Градиент по Y

# Объединение градиентов по X и Y
sobel_combined = cv.addWeighted(np.absolute(sobelx), 0.5, np.absolute(sobely), 0.5, 0)
sobel_combined = np.uint8(sobel_combined)

# Показ результатов Собеля
cv.imshow('Sobel X', np.uint8(np.absolute(sobelx)))
cv.imshow('Sobel Y', np.uint8(np.absolute(sobely)))
cv.imshow('Sobel Combined', sobel_combined)

# Ожидание нажатия клавиши и закрытие окон
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# **Распознование лиц. Каскады Хаара**
#
# Каскады Хаара — способ обнаружения объектов на изображении, основанный на машинном обучении. Идея метода была предложена Полом Виолой и Майклом Джонсом.
#
# Каскады Хаара представляют собой набор классификаторов, которые обучаются на большом количестве положительных и отрицательных примеров исходного объекта. Затем они применяются к изображению в виде «каскада», где более простые классификаторы рассматриваются первыми для быстрого отсеивания большого числа негативных областей, а более сложные классификаторы используются позднее для более точной проверки.
#
# На этапе обучения алгоритм тренируется на большом наборе тестовых изображений, которые содержат как положительные (изображения с объектами, которые нужно обнаружить), так и отрицательные (изображения без объектов интереса) примеры. Для каждого объекта на положительных изображениях извлекаются характерные признаки Хаара. Они представляют собой яркие различия в разных областях изображения.
#
# Процесс обнаружения начинается с применения первого этапа каскада к изображению. Если этап не прошёл, изображение отклоняется. Если прошёл, то изображение передаётся следующему этапу, и так далее. Когда все этапы каскада успешно пройдены, объект считается обнаруженным.
#
# Каскады Хаара предоставляют высокую скорость обнаружения и могут использоваться для различных типов объектов: лиц, глаз, автомобилей и других.

# %%
import cv2 as cv
import numpy as np

img = cv.imread('man.jpg')
cv.imshow('Man', img)

gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
cv.imshow('Gray',  gray)

hear_cascade = cv.CascadeClassifier('haarcascade_frontalface_default.xml')
faces_rect = hear_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=3)

print(f'Number of faces found = {len(faces_rect)}')

for(x,y,w,h) in faces_rect:
    cv.rectangle(img, (x,y), (x+w,y+h), (0,255,0), thickness=2)
cv.waitKey(0)

# %% [markdown]
# Датасетк - .xml файл

# %% [markdown]
# https://www.kaggle.com/ - датасеты
# CVAT - разметка данных
# Huggin Face - датасеты и модели
